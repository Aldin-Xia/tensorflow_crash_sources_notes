# %% [markdown]
# <a href="https://colab.research.google.com/github/Aldin-Xia/tensorflow_crash_sources_notes/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
from IPython import display
from matplotlib import cm
from matplotlib import gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import metrics
import tensorflow as tf
from tensorflow.python.data import Dataset

california_housing_dataframe = pd.read_csv(
    "https://download.mlcc.google.cn/mledu-datasets/california_housing_train.csv", sep=",")
california_housing_dataframe = california_housing_dataframe.reindex(
    np.random.permutation(california_housing_dataframe.index))
california_housing_dataframe["median_house_value"] /= 1000.0
california_housing_dataframe.describe()


def train_model(learning_rate, steps, batch_size, input_feature='total_rooms'):
    '''Trains a linear regression model of one feature

    Args:
        learning_reate: A 'float', the learning reate.
        steps: A non-zero 'int', the total number of traning steps. A training step consists of a foreard and backward pass using a single batch.
        batch_size: A non-zero 'int', the batch size.
        input_feature: A 'string' specifying a column from 'caligornia_housing_datafram' to use as input feature
    '''

    periods = 10
    steps_per_period = steps/periods
    # 1、定义特征
    my_feature = input_feature
    my_feature_data = california_housing_dataframe[[my_feature]]

    # 2、配置特征列
    feature_columns = [tf.feature_column.numeric_column(my_feature)]

    # 3、定义标签（目标）
    my_label = 'median_house_value'
    targets = california_housing_dataframe[my_label]

    # 4 创建输入函数
    training_input_fn = lambda: my_input_fn(
        my_feature_data, targets, batch_size=batch_size)

    prediction_input_fn = lambda:my_input_fn(
        my_feature_data, targets, num_epochs=1, shuffle=False)

    # 5 创建先行回归对象
    my_optimizer = tf.train.GradientDescentOptimizer(
        learning_rate=learning_rate)
    my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(
        my_optimizer, 5.0)
    linear_regressor = tf.estimator.LinearRegressor(
        feature_columns=feature_columns, optimizer=my_optimizer)

    plt.figure(figsize=(15, 6))
    plt.subplot(1, 2, 1)
    plt.title('Learned Line by Period')
    plt.ylabel(my_label)
    plt.xlabel(my_feature)
    sample = california_housing_dataframe.sample(n=300)
    plt.scatter(sample[my_feature], sample[my_label], c='g')
    colors = [cm.coolwarm(x) for x in np.linspace(-1, 1, periods)]
    # Train the model, but do so inside a loop so that we can periodically assess
    # loss metrics.
    print("Training model...")
    print("RMSE (on training data):")
    root_mean_squared_errors = []
    for period in range(0, periods):
        # Train the model, starting from the prior state.
        linear_regressor.train(
            input_fn=training_input_fn,
            steps=steps_per_period
        )
        # Take a break and compute predictions.
        predictions = linear_regressor.predict(input_fn=prediction_input_fn)
        predictions = np.array([item['predictions'][0]
                                for item in predictions])

        # Compute loss.
        root_mean_squared_error = math.sqrt(
            metrics.mean_squared_error(predictions, targets))
        # Occasionally print the current loss.
        print("  period %02d : %0.2f" % (period, root_mean_squared_error))
        # Add the loss metrics from this period to our list.
        root_mean_squared_errors.append(root_mean_squared_error)
        # Finally, track the weights and biases over time.
        # Apply some math to ensure that the data and line are plotted neatly.
        y_extents = np.array([0, sample[my_label].max()])

        weight = linear_regressor.get_variable_value(
            'linear/linear_model/%s/weights' % input_feature)[0]
        bias = linear_regressor.get_variable_value(
            'linear/linear_model/bias_weights')

        x_extents = (y_extents - bias) / weight
        x_extents = np.maximum(np.minimum(x_extents,
                                          sample[my_feature].max()),
                               sample[my_feature].min())
        y_extents = weight * x_extents + bias
        plt.plot(x_extents, y_extents, color=colors[period])
    print("Model training finished.")


train_model(learning_rate=0.00001, steps=100, batch_size=1)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpxcu6zwbg
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpxcu6zwbg', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0171397d30>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Training model...
# RMSE (on training data):
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 3364.0, step = 1
# INFO:tensorflow:Saving checkpoints for 10 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 9135.384.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 00 : 236.32
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 96212.875, step = 11
# INFO:tensorflow:Saving checkpoints for 20 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 18287.787.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-20
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 01 : 235.11
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-20
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 10185.251, step = 21
# INFO:tensorflow:Saving checkpoints for 30 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 4799.1973.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 02 : 233.90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 30 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 247259.14, step = 31
# INFO:tensorflow:Saving checkpoints for 40 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 8072.8276.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-40
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 03 : 232.70
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-40
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 40 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 44979.656, step = 41
# INFO:tensorflow:Saving checkpoints for 50 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 19431.959.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 04 : 231.50
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 50 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 232427.75, step = 51
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 21530.816.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 05 : 230.31
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 29449.348, step = 61
# INFO:tensorflow:Saving checkpoints for 70 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 20046.557.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-70
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 06 : 229.13
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-70
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 70 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 245790.94, step = 71
# INFO:tensorflow:Saving checkpoints for 80 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 63091.8.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 07 : 227.96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 80 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 58691.895, step = 81
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 7429.3086.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 08 : 226.79
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:loss = 24954.55, step = 91
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/tmpxcu6zwbg/model.ckpt.
# INFO:tensorflow:Loss for final step: 41141.15.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxcu6zwbg/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#   period 09 : 225.63
# Model training finished.
